# %% [markdown]
# # 4.6 Merging Instacart Data Exercise

# %% [markdown]
# ## Steps:
# ## 1. Download the new data set.
# ## 2. Unzip the file and move it into your project folder.
# ## 3. Import the data set into Jupyter as a new dataframe: df_ords_prior.
# ## 4. Check the dimensions of the imported dataframe.
# ## 5. Merge the dataframe with your df_ords dataframe.
# ## 6. Use the indicator argument to check whether there was a full match between the two dataframes.

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 1. Download the new data set.
# ### Done.

# %% [markdown]
# ## 2. Unzip the file and move it into your project folder.
# ### Done.

# %% [markdown]
# ## 3. Import the data set into Jupyter as a new dataframe: df_ords_prior.

# %%
# Making a path.
path = r'/Users/terencekeys/Downloads/Shawzz Folder/06-2023 Instacart Basket Analysis'

# %%
# Importing order_products__prior file as df_ords_prior.
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products__prior.csv'), index_col = False)

# %%
# Importing df_ords_4.5 file as df_ords.
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_ords_4.5.csv'), index_col = False)

# %%
# Checking the output of first 5 rows for df_ords_prior dataframe.
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Checking the output of first 5 rows for df_ords dataframe.
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           1   2398795        1    prior             2          3
# 2           2    473747        1    prior             3          3
# 3           3   2254736        1    prior             4          4
# 4           4    431534        1    prior             5          4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %% [markdown]
# ## 4. Check the dimensions of the imported dataframe.

# %%
# Checking the output of dimensions of df_ords_prior dataframe.
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
# Checking the output of dimensions of df_ords dataframe.
df_ords.shape
# Out:
# (3421083, 8)

# %% [markdown]
# ## 5. Merge the dataframe with your df_ords dataframe.

# %%
# Merging df_ords_prior dataframe and df_ords dataframe together.
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
# Checking the output of the first 5 rows of df_merged_large dataframe.
df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           0   2539329        1    prior             1          2
# 2           0   2539329        1    prior             1          2
# 3           0   2539329        1    prior             1          2
# 4           0   2539329        1    prior             1          2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %% [markdown]
# ## 6. Use the indicator argument to check whether there was a full match between the two dataframes.

# %%
# Checking the output.
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# ## Exporting to pkl format.

# %%
# Export data to pkl.
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # 4.6 Merging Instacart Data TASK

# %% [markdown]
# ## 1. If you haven’t merged your prepared Instacart orders data with the new orders_products_prior dataframe per the instructions in this Exercise, do so now.
# ### Done.

# %% [markdown]
# ## 2. Export the merged file in pickle format as “orders_products_combined.pkl”.
# ### Done.

# %% [markdown]
# ## 3. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
# Making a pathway to dataframes.
path = r'/Users/terencekeys/Downloads/Shawzz Folder/06-2023 Instacart Basket Analysis/02 Data/Prepared Data'

# %%
# Importing orders_products_combined dataframe.
df_ords_prods_comb = pd.read_pickle(os.path.join(path, 'orders_products_combined.pkl'))

# %% [markdown]
# ## 4. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
# Checking the shape of the df_ords_prods_comb dataframe.
df_ords_prods_comb.shape
# Out:
# (32434489, 12)

# %% [markdown]
# ## 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
# Importing the df_prods_clean_no_dups dataframe.
df_prods_clean_no_dups = pd.read_csv(os.path.join(path, 'df_prods_clean_no_dups_4.5.csv'), index_col = False)

# %%
# Checking  the shape of the df_prods_clean_no_dups dataframe.
df_prods_clean_no_dups.shape
# Out:
# (49672, 6)

# %%
# Looking at the first 5 rows of the df_ords_prods_comb dataframe.
df_ords_prods_comb.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0           0   2539329        1    prior             1          2
# 1           0   2539329        1    prior             1          2
# 2           0   2539329        1    prior             1          2
# 3           0   2539329        1    prior             1          2
# 4           0   2539329        1    prior             1          2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# ...

# %%
# Looking at first 5 rows in df_prods_clean_no_dups dataframe.
df_prods_clean_no_dups.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Merging the df_ords_prods_comb and df_prods_clean_no_dups dataframes together.
df_merged = df_ords_prods_comb.merge(df_prods_clean_no_dups, on = 'product_id', indicator = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Merging the df_ords_prods_comb and df_prods_clean_no_dups dataframes together.
# ----> 2 df_merged = df_ords_prods_comb.merge(df_prods_clean_no_dups, on = 'product_id', indicator = True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
# ...

# %%
# Dropping the merge column.
df_ords_prods_comb = df_ords_prods_comb.drop(columns = ['_merge'])

# %%
df_ords_prods_comb
# Out:
#           Unnamed: 0  order_id  user_id eval_set  order_number  order_dow  \
# 0                  0   2539329        1    prior             1          2
# 1                  0   2539329        1    prior             1          2
# 2                  0   2539329        1    prior             1          2
# 3                  0   2539329        1    prior             1          2
# 4                  0   2539329        1    prior             1          2
# ...              ...       ...      ...      ...           ...        ...
# 32434484     3421081   2977660   206209    prior            13          1
# 32434485     3421081   2977660   206209    prior            13          1
# 32434486     3421081   2977660   206209    prior            13          1
# 32434487     3421081   2977660   206209    prior            13          1
# 32434488     3421081   2977660   206209    prior            13          1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# ...

# %%
# Merging df_ords_prods_comb and df_prods_clean_no_dups together.
df_merged = df_ords_prods_comb.merge(df_prods_clean_no_dups, on = 'product_id', indicator = True)

# %%
df_merged
# Out:
#           Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0                    0   2539329        1    prior             1          2
# 1                    1   2398795        1    prior             2          3
# 2                    2    473747        1    prior             3          3
# 3                    3   2254736        1    prior             4          4
# 4                    4    431534        1    prior             5          4
# ...                ...       ...      ...      ...           ...        ...
# 32404854       3360493   1320836   202557    prior            17          2
# 32404855       3360494     31526   202557    prior            18          5
# 32404856       3376038    758936   203436    prior             1          2
# 32404857       3376039   2745165   203436    prior             2          3
# 32404858       3408036   3093936   205420    prior             1          4
#
# ...

# %%
# Droping the unnamed columns.
df_merged = df_merged.drop(columns = ['Unnamed: 0_x','Unnamed: 0_y'])

# %%
df_merged
# Out:
#           order_id  user_id eval_set  order_number  order_dow  \
# 0          2539329        1    prior             1          2
# 1          2398795        1    prior             2          3
# 2           473747        1    prior             3          3
# 3          2254736        1    prior             4          4
# 4           431534        1    prior             5          4
# ...            ...      ...      ...           ...        ...
# 32404854   1320836   202557    prior            17          2
# 32404855     31526   202557    prior            18          5
# 32404856    758936   203436    prior             1          2
# 32404857   2745165   203436    prior             2          3
# 32404858   3093936   205420    prior             1          4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %% [markdown]
# ## 6. Confirm the results of the merge using the merge flag.

# %%
# Confirming the results.
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# ## 7. Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size).

# %%
# Merging df_merged to the Prepared Data Folder as orders_products_merged.
df_merged.to_pickle(os.path.join(path, 'orders_products_merged.pkl'))
